# %% [markdown]
# # Chapter 07. Visualization

# %% [markdown]
# ## Scatter Plots and Line Graphs
#
#
#
# Import packages

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')  # 그래프 그릴 때 테마를 fivethirtyeight

# %% [markdown]
# Load a CSV file with Table.read_table()

# %%
path_data = "https://raw.githubusercontent.com/mlee-pnu/IDS/main/FDS07/"
actors = pd.read_csv(path_data + 'actors.csv')
# actors[:3]
actors
# Out:
#                      Actor  Total Gross  Number of Movies  Average per Movie  \
# 0            Harrison Ford       4871.7                41              118.8
# 1        Samuel L. Jackson       4772.8                69               69.2
# 2           Morgan Freeman       4468.3                61               73.3
# 3                Tom Hanks       4340.8                44               98.7
# 4       Robert Downey, Jr.       3947.3                53               74.5
# 5             Eddie Murphy       3810.4                38              100.3
# 6               Tom Cruise       3587.2                36               99.6
# 7              Johnny Depp       3368.6                45               74.9
# 8            Michael Caine       3351.5                58               57.8
# 9       Scarlett Johansson       3341.2                37               90.3
# 10             Gary Oldman       3294.0                38               86.7
# 11          Robin Williams       3279.3                49               66.9
# 12            Bruce Willis       3189.4                60               53.2
# 13       Stellan Skarsgard       3175.0                43               73.8
# 14         Anthony Daniels       3162.9                 7              451.8
# 15            Ian McKellen       3150.4                31              101.6
# 16              Will Smith       3149.1                24              131.2
# 17           Stanley Tucci       3123.9                50               62.5
# 18              Matt Damon       3107.3                39               79.7
# 19           Robert DeNiro       3081.3                79               39.0
# 20            Cameron Diaz       3031.7                34               89.2
# 21             Liam Neeson       2942.7                63               46.7
# 22             Andy Serkis       2890.6                23              125.7
# 23             Don Cheadle       2885.4                34               84.9
# 24             Ben Stiller       2827.0                37               76.4
# 25    Helena Bonham Carter       2822.0                36               78.4
# 26           Orlando Bloom       2815.8                17              165.6
# 27         Woody Harrelson       2815.8                50               56.3
# 28          Cate Blanchett       2802.6                39               71.9
# 29           Julia Roberts       2735.3                42               65.1
# 30         Elizabeth Banks       2726.3                35               77.9
# 31           Ralph Fiennes       2715.3                36               75.4
# 32             Emma Watson       2681.9                17              157.8
# 33         Tommy Lee Jones       2681.3                46               58.3
# 34               Brad Pitt       2680.9                40               67.0
# 35            Adam Sandler       2661.0                32               83.2
# 36        Daniel Radcliffe       2634.4                17              155.0
# 37              Jonah Hill       2605.1                29               89.8
# 38             Owen Wilson       2602.3                39               66.7
# 39              Idris Elba       2580.6                26               99.3
# 40          Bradley Cooper       2557.7                25              102.3
# 41           Mark Wahlberg       2549.8                36               70.8
# 42              Jim Carrey       2545.2                27               94.3
# 43          Dustin Hoffman       2522.1                43               58.7
# 44       Leonardo DiCaprio       2518.3                25              100.7
# 45           Jeremy Renner       2500.3                21              119.1
# 46  Philip Seymour Hoffman       2463.7                40               61.6
# 47          Sandra Bullock       2462.6                35               70.4
# 48             Chris Evans       2457.8                23              106.9
# 49           Anne Hathaway       2416.5                25               96.7
#
#                                #1 Movie  Gross
# 0          Star Wars: The Force Awakens  936.7
# 1                          The Avengers  623.4
# 2                       The Dark Knight  534.9
# 3                           Toy Story 3  415.0
# 4                          The Avengers  623.4
# 5                               Shrek 2  441.2
# 6                     War of the Worlds  234.3
# 7                      Dead Man's Chest  423.3
# 8                       The Dark Knight  534.9
# 9                          The Avengers  623.4
# 10                      The Dark Knight  534.9
# 11                  Night at the Museum  250.9
# 12                          Sixth Sense  293.5
# 13                         The Avengers  623.4
# 14         Star Wars: The Force Awakens  936.7
# 15                   Return of the King  377.8
# 16                     Independence Day  306.2
# 17                        Catching Fire  424.7
# 18                          The Martian  228.4
# 19                     Meet the Fockers  279.3
# 20                              Shrek 2  441.2
# 21                   The Phantom Menace  474.5
# 22         Star Wars: The Force Awakens  936.7
# 23              Avengers: Age of Ultron  459.0
# 24                     Meet the Fockers  279.3
# 25  Harry Potter / Deathly Hallows (P2)  381.0
# 26                     Dead Man's Chest  423.3
# 27                        Catching Fire  424.7
# 28                   Return of the King  377.8
# 29                       Ocean's Eleven  183.4
# 30                        Catching Fire  424.7
# 31  Harry Potter / Deathly Hallows (P2)  381.0
# 32  Harry Potter / Deathly Hallows (P2)  381.0
# 33                         Men in Black  250.7
# 34                          World War Z  202.4
# 35                 Hotel Transylvania 2  169.7
# 36  Harry Potter / Deathly Hallows (P2)  381.0
# 37                       The LEGO Movie  257.8
# 38                  Night at the Museum  250.9
# 39              Avengers: Age of Ultron  459.0
# 40                      American Sniper  350.1
# 41                       Transformers 4  245.4
# 42                           The Grinch  260.0
# 43                     Meet the Fockers  279.3
# 44                              Titanic  658.7
# 45                         The Avengers  623.4
# 46                        Catching Fire  424.7
# 47                              Minions  336.0
# 48                         The Avengers  623.4
# 49                The Dark Knight Rises  448.1

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# #### Number of Movies vs. Total Gross

# %%
x = actors['Number of Movies']
y = actors['Total Gross']
plt.scatter(x, y, color='black', alpha=0.5)
plt.xlabel('Number of Movies', fontsize=16)
plt.ylabel('Total Gross', fontsize=16)
plt.show()

# %%
actors.plot.scatter(x='Number of Movies',
                    y='Total Gross')  # actor라는 dataframe 자체에서 plot.scater를 call 해서 scatter plot 생성
actors.shape  #(50, 6) scatter의 점은 하나의 individual을 나타내므로 50개의 점이 존재한다.
# Out:
# (50, 6)

# %% [markdown]
# Do you see any associations?

# %% [markdown]
# #### Number of Movies vs. Average per Movie

# %%
x = actors['Number of Movies']
y = actors['Average per Movie']
plt.scatter(x, y, color='black', alpha=0.5)
plt.xlabel('Number of Movies', fontsize=16)
plt.ylabel('Average per Movie', fontsize=16)
plt.show()

# %%
no_outlier = actors.where(actors['Number of Movies'] > 10).where(actors['Number of Movies'] < 60)
no_outlier.plot.scatter('Number of Movies', 'Average per Movie')  # outlier 존재
# Out:
# <Axes: xlabel='Number of Movies', ylabel='Average per Movie'>

# %% [markdown]
# Any associations?
#
# Except for the very top point, it seems there is a negative association.

# %%
no_outlier = actors[actors['Number of Movies'] > 10]
no_outlier.plot.scatter('Number of Movies', 'Average per Movie')
# Out:
# <Axes: xlabel='Number of Movies', ylabel='Average per Movie'>

# %%
# eliminate the outlier
no_outlier = actors[actors['Number of Movies'] > 10]

x = no_outlier['Number of Movies']
y = no_outlier['Average per Movie']
plt.scatter(x, y, color='black', alpha=0.5)
plt.xlabel('Number of Movies', fontsize=16)
plt.ylabel('Average per Movie', fontsize=16)
plt.show()

# %% [markdown]
# Who are those actors who appear in more than 60 movies?

# %%
# Filter the actors who have been in more than 60 movies
actors[actors['Number of Movies'] > 60]
# Out:
#                 Actor  Total Gross  Number of Movies  Average per Movie  \
# 1   Samuel L. Jackson       4772.8                69               69.2
# 2      Morgan Freeman       4468.3                61               73.3
# 19      Robert DeNiro       3081.3                79               39.0
# 21        Liam Neeson       2942.7                63               46.7
#
#               #1 Movie  Gross
# 1         The Avengers  623.4
# 2      The Dark Knight  534.9
# 19    Meet the Fockers  279.3
# 21  The Phantom Menace  474.5

# %% [markdown]
# Who is the outlier?

# %%
# Filter the actors who have been in less than 60 movies
actors[actors['Number of Movies'] < 10]
# Out:
#               Actor  Total Gross  Number of Movies  Average per Movie  \
# 14  Anthony Daniels       3162.9                 7              451.8
#
#                         #1 Movie  Gross
# 14  Star Wars: The Force Awakens  936.7

# %%
actors[(actors['Number of Movies'] < 10) | (actors['Number of Movies'] > 60)]
# Out:
#                 Actor  Total Gross  Number of Movies  Average per Movie  \
# 1   Samuel L. Jackson       4772.8                69               69.2
# 2      Morgan Freeman       4468.3                61               73.3
# 14    Anthony Daniels       3162.9                 7              451.8
# 19      Robert DeNiro       3081.3                79               39.0
# 21        Liam Neeson       2942.7                63               46.7
#
#                         #1 Movie  Gross
# 1                   The Avengers  623.4
# 2                The Dark Knight  534.9
# 14  Star Wars: The Force Awakens  936.7
# 19              Meet the Fockers  279.3
# 21            The Phantom Menace  474.5

# %% [markdown]
# ### Line Plots

# %% [markdown]
# Read the movies_by_year data

# %%
# Read csv movies_by_year
movies_by_year = pd.read_csv(path_data + 'movies_by_year.csv')
movies_by_year[:3]
# Out:
#    Year  Total Gross  Number of Movies                      #1 Movie
# 0  2015      11128.5               702  Star Wars: The Force Awakens
# 1  2014      10360.8               702               American Sniper
# 2  2013      10923.6               688                 Catching Fire

# %% [markdown]
# Plot the number of movies by year

# %%
movies_in_21c_by_year = movies_by_year.where(movies_by_year['Year'] > 2000)
movies_in_21c_by_year.plot('Year', 'Number of Movies')
# movies_by_year.plot('Year','Number of Movies')
# movies_by_year.plot('Year','Number of Movies','line')
# movies_by_year.plot.line('Year','Number of Movies')
# Out:
# <Axes: xlabel='Year'>

# %%
x = movies_by_year['Year']
y = movies_by_year['Number of Movies']
plt.plot(x, y, color='black', alpha=0.5)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of Movies', fontsize=16)
plt.show()

# %% [markdown]
# What happened in the early 80s?
#
# Let's focus on the 21st century.

# %%
century_21 = movies_by_year[movies_by_year.Year > 1999]
century_21.plot('Year', 'Number of Movies')
# Out:
# <Axes: xlabel='Year'>

# %%
century_21 = movies_by_year[movies_by_year.Year > 1999]

x = century_21['Year']
y = century_21['Number of Movies']
plt.plot(x, y, color='black', alpha=0.5)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of Movies', fontsize=16)
plt.show()

# %% [markdown]
# You can see how the global financial crisis affected the number of movies released.
#
# Was the total gross of the movie industry also affected?

# %%
century_21.plot('Year', 'Total Gross')  # 왜 2009년도에 갑자기 올라갔는가? -> 아바타 개봉
# Out:
# <Axes: xlabel='Year'>

# %%
x = century_21['Year']
y = century_21['Total Gross']
plt.plot(x, y, color='black', alpha=0.5)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Total Gross', fontsize=16)
plt.show()

# %% [markdown]
# Any unlikely patterns?

# %%
# Filter year 2009
century_21[century_21.Year == 2009]
# Out:
#    Year  Total Gross  Number of Movies #1 Movie
# 6  2009      10595.5               521   Avatar

# %% [markdown]
# ## 7.1 Visualizing Categorical Distributions

# %% [markdown]
# The table `icecream` contains data on 30 cartons of ice-cream.

# %%
# Make table named icecream
icecream = pd.DataFrame({
    'Flavor': np.array(['Chocolate', 'Strawberry', 'Vanilla']),
    'Number of Cartons': np.array([16, 5, 9])
})
icecream
# Out:
#        Flavor  Number of Cartons
# 0   Chocolate                 16
# 1  Strawberry                  5
# 2     Vanilla                  9

# %%
icecream.plot.barh('Flavor')  # barh = bar horizontal
# Out:
# <Axes: ylabel='Flavor'>

# %%
# icecream.plot('Flavor', 'Number of Cartons','barh')
icecream.plot.barh('Flavor', 'Number of Cartons')  # categorical value, numerical value 순서로 넘겨준다.
# Out:
# <Axes: ylabel='Flavor'>

# %%
x = icecream['Number of Cartons']
y = icecream['Flavor']

plt.barh(y, x, color='darkblue')
plt.xlabel('Number of Cartons')
plt.ylabel('Flavor')
plt.show()

# %%
x = icecream['Number of Cartons']
y = icecream['Flavor']

plt.barh(y, x, color='darkblue', tick_label=y)
plt.xlabel('Number of Cartons')
plt.ylabel('Flavor')
plt.show()

# %% [markdown]
# ### 7.1.2. Design Aspects of Bar Charts

# %%
icecream.sort_values(by='Number of Cartons').plot.barh('Flavor')
# Out:
# <Axes: ylabel='Flavor'>

# %%
icecream = icecream.sort_values(by=['Number of Cartons'])

x = icecream['Number of Cartons']
y = icecream['Flavor']

plt.barh(y, x, color='darkblue')
plt.xlabel('Number of Cartons')
plt.ylabel('Flavor')
plt.show()

# %% [markdown]
# ### 7.1.3. Grouping Categorical Data

# %%
# Read table
top = pd.read_csv(path_data + 'top_movies_2017.csv')
top
# Out:
#                                   Title           Studio      Gross  \
# 0                    Gone with the Wind              MGM  198676459
# 1                             Star Wars              Fox  460998007
# 2                    The Sound of Music              Fox  158671368
# 3           E.T.: The Extra-Terrestrial        Universal  435110554
# 4                               Titanic        Paramount  658672302
# ..                                  ...              ...        ...
# 195                              9 to 5              Fox  103290500
# 196  Batman v Superman: Dawn of Justice  Warner Brothers  330360194
# 197                            The Firm        Paramount  158348367
# 198                       Suicide Squad  Warner Brothers  325100054
# 199             Who Framed Roger Rabbit      Buena Vista  156452370
#
#      Gross (Adjusted)  Year
# 0          1796176700  1939
# 1          1583483200  1977
# 2          1266072700  1965
# 3          1261085000  1982
# 4          1204368000  1997
# ..                ...   ...
# 195         341357800  1980
# 196         340137000  2016
# 197         340028200  1993
# 198         339411900  2016
# 199         338409100  1988
#
# [200 rows x 5 columns]

# %% [markdown]
# Aggregate the number of movies released by each studio

# %%
# Filter 'Title' and 'Studio'
movies_and_studios = top.loc[:, ['Title',
                                 'Studio']]  # top이 DataFrame ,모든 individual에 대해 Title,과 Studio만을 Feature로 가지게 하여 새로운 DF로 빼낸다.
studio_distribution = movies_and_studios.groupby('Studio') \
    .size().reset_index(name='count')  # Studio별로 몇 편씩 있는지 집계한다.
# Or
# movies_and_studios.groupby('Studio')['Studio'].count().reset_index(name='count')
studio_distribution
# Out:
#                   Studio  count
# 0                   AVCO      1
# 1            Buena Vista     35
# 2               Columbia      9
# 3                 Disney     11
# 4             Dreamworks      3
# 5                    Fox     24
# 6                    IFC      1
# 7              Lionsgate      3
# 8                    MGM      7
# 9                  Metro      1
# 10                    NM      1
# 11               Newline      5
# 12                 Orion      1
# 13             Paramount     25
# 14  Paramount/Dreamworks      4
# 15                   RKO      3
# 16                 Selz.      1
# 17                  Sony      4
# 18                  Sum.      1
# 19               Tristar      2
# 20        United Artists      6
# 21             Universal     23
# 22       Warner Brothers     29

# %%
sum(studio_distribution['count'])
# Out:
# 200

# %%
studio_distribution.sort_values(by='count').plot.barh('Studio')
# Out:
# <Axes: ylabel='Studio'>

# %%
# Distribution
studio_distribution = movies_and_studios.groupby('Studio')['Studio'].count().reset_index(name='count')

studio_distribution = studio_distribution.sort_values(by=['count'])

x = studio_distribution['count']
y = studio_distribution['Studio']

plt.barh(y, x, color='darkblue')
plt.xlabel('count')
plt.ylabel('Studio')
plt.show()

# %% [markdown]
# ### 7.1.4. Towards Quantitative Variables

# %%
movies_and_years = top.loc[:, ['Title', 'Year']]
movies_and_years.groupby('Year').size().reset_index(name='count')[:10]
# movies_and_years.groupby('Year')['Year'].count().reset_index(name='count')[:10]
# Out:
#    Year  count
# 0  1921      1
# 1  1937      1
# 2  1939      1
# 3  1940      1
# 4  1941      2
# 5  1942      1
# 6  1945      1
# 7  1946      2
# 8  1950      1
# 9  1952      1

# %%
movies_and_years.groupby('Year')['Year'].count().reset_index(name='count')[:10] \
    .sort_values(by='Year', ascending=False).plot.barh('Year') # count는 series로 바꿔야 된다.
# Out:
# <Axes: ylabel='Year'>

# %%
# Distribution
movies_and_years = top.loc[:, ['Title', 'Year']]
movies_and_years = movies_and_years.groupby('Year')['Year'].count().reset_index(name='count')

x = movies_and_years['count'][:10]
y = movies_and_years['Year'].astype(str)[:10]
print(y)

plt.barh(y, x, color='darkblue')
plt.xlabel('count')
plt.ylabel('Year')
plt.show()
# Out:
# 0    1921
# 1    1937
# 2    1939
# 3    1940
# 4    1941
# 5    1942
# 6    1945
# 7    1946
# 8    1950
# 9    1952
# Name: Year, dtype: object

# %%
movies_and_years = top.loc[:, ['Title', 'Year']]
movies_and_years = movies_and_years.groupby('Year')['Year'].count().reset_index(name='count')
movies_and_years
# Out:
#     Year  count
# 0   1921      1
# 1   1937      1
# 2   1939      1
# 3   1940      1
# 4   1941      2
# ..   ...    ...
# 67  2013      4
# 68  2014      3
# 69  2015      6
# 70  2016      9
# 71  2017      3
#
# [72 rows x 2 columns]

# %% [markdown]
# ## 7.2. Visualizing Numerical Distributions

# %%
# Read table
top = pd.read_csv(path_data + 'top_movies_2017.csv') # path_data에서 top_movei_2017을 가져올 수 있게 한다
top
# Out:
#                                   Title           Studio      Gross  \
# 0                    Gone with the Wind              MGM  198676459
# 1                             Star Wars              Fox  460998007
# 2                    The Sound of Music              Fox  158671368
# 3           E.T.: The Extra-Terrestrial        Universal  435110554
# 4                               Titanic        Paramount  658672302
# ..                                  ...              ...        ...
# 195                              9 to 5              Fox  103290500
# 196  Batman v Superman: Dawn of Justice  Warner Brothers  330360194
# 197                            The Firm        Paramount  158348367
# 198                       Suicide Squad  Warner Brothers  325100054
# 199             Who Framed Roger Rabbit      Buena Vista  156452370
#
#      Gross (Adjusted)  Year
# 0          1796176700  1939
# 1          1583483200  1977
# 2          1266072700  1965
# 3          1261085000  1982
# 4          1204368000  1997
# ..                ...   ...
# 195         341357800  1980
# 196         340137000  2016
# 197         340028200  1993
# 198         339411900  2016
# 199         338409100  1988
#
# [200 rows x 5 columns]

# %%
# Make a new table millions
millions = pd.DataFrame({'Title': top['Title'], 
                         'Adjusted Gross': np.round(top['Gross (Adjusted)'] / 1e6, 2)}) # 숫자가 커서 처리 함 # top DataFrame의 'Title'열을 millions의 'Title' 열에 넣는다.
millions
# Out:
#                                   Title  Adjusted Gross
# 0                    Gone with the Wind         1796.18
# 1                             Star Wars         1583.48
# 2                    The Sound of Music         1266.07
# 3           E.T.: The Extra-Terrestrial         1261.08
# 4                               Titanic         1204.37
# ..                                  ...             ...
# 195                              9 to 5          341.36
# 196  Batman v Superman: Dawn of Justice          340.14
# 197                            The Firm          340.03
# 198                       Suicide Squad          339.41
# 199             Who Framed Roger Rabbit          338.41
#
# [200 rows x 2 columns]

# %% [markdown]
# ### 7.2.1. Binning the Data

# %%
adj_gross = millions['Adjusted Gross'] # 'Adjusted Gross 열을 adj_grss로
min(adj_gross), max(adj_gross) # gross의 min,max 왜? binning 구간, 338~1797(정수범위)
# Out:
# (338.41, 1796.18)

# %%
# Calculate bins
# Define bins range
bins_range = np.arange(300, 2001, 100) # 2001은 exclusive, 300부터 2000까지

# Method1: Construct bins and Delay Count
bins = pd.cut(millions['Adjusted Gross'], bins_range, right=False).value_counts().reset_index(
    name='Adjusted Gross Count')
# value_counts()와 count()의 차이?
bins.rename(columns={'Adjusted Gross': 'bins'}, inplace=True)

'''
# Method2: Construct bins and Delay Count
bins = millions.groupby(pd.cut(millions['Adjusted Gross'], bins_range, right=False))
bins = pd.DataFrame(bins['Adjusted Gross'].count().reset_index(name='Adjusted Gross Count'))
bins.rename(columns={'Adjusted Gross': 'bins'}, inplace=True)
bins
'''

bins
# Out:
#             bins  Adjusted Gross Count
# 0     [300, 400)                    68
# 1     [400, 500)                    60
# 2     [500, 600)                    32
# 3     [600, 700)                    15
# 4     [700, 800)                     7
# 5     [800, 900)                     7
# 6   [1200, 1300)                     3
# 7   [1100, 1200)                     3
# 8    [900, 1000)                     3
# 9   [1500, 1600)                     1
# 10  [1700, 1800)                     1
# 11  [1000, 1100)                     0
# 12  [1300, 1400)                     0
# 13  [1400, 1500)                     0
# 14  [1600, 1700)                     0
# 15  [1800, 1900)                     0
# 16  [1900, 2000)                     0

# %%
bins_range = np.arange(300, 2001, 100) / 100
#bins_range
fig, ax = plt.subplots()
## x축 눈금 레이블이 표시될 x좌표 위치
xtick_label_position = list(range(len(bins_range) - 1))
#xtick_label_position
## x축 눈금 레이블 출력을 bins['bins']에 저장된 값으로 설정
plt.xticks(xtick_label_position, bins['bins'], rotation=270)
ax.bar(xtick_label_position, bins['Adjusted Gross Count'])
plt.show()

# %%
bins = pd.cut(millions['Adjusted Gross'], 11, right=False).value_counts() \
    .reset_index(name='Adjusted Gross Count') # bin을 몇 개로 쪼갤지, 11개로 분리
bins.rename(columns={'Adjusted Gross': 'bins'}, inplace=True)
bins
# Out:
#                     bins  Adjusted Gross Count
# 0      [338.41, 470.935)                   106
# 1     [470.935, 603.459)                    55
# 2     [603.459, 735.984)                    16
# 3     [735.984, 868.508)                     9
# 4    [868.508, 1001.033)                     6
# 5   [1133.557, 1266.082)                     5
# 6   [1001.033, 1133.557)                     1
# 7   [1531.131, 1663.655)                     1
# 8   [1663.655, 1797.638)                     1
# 9   [1266.082, 1398.606)                     0
# 10  [1398.606, 1531.131)                     0

# %%
bins = pd.cut(millions['Adjusted Gross'], 5).value_counts().reset_index(name='Adjusted Gross Count')
bins.rename(columns={'index': 'bins'}, inplace=True)
bins
# Out:
#          Adjusted Gross  Adjusted Gross Count
# 0    (336.952, 629.964]                   165
# 1    (629.964, 921.518]                    24
# 2   (921.518, 1213.072]                     7
# 3  (1213.072, 1504.626]                     2
# 4   (1504.626, 1796.18]                     2

# %% [markdown]
# ### 7.2.2. Histogram

# %%
# Density Scale
bins['Percent'] = bins.loc[:, 'Adjusted Gross Count'] \
                  / sum(bins.loc[:, 'Adjusted Gross Count']) * 100
bins['Height'] = bins.loc[:, 'Adjusted Gross Count'] \
                 / sum(bins.loc[:, 'Adjusted Gross Count'])
bins
# Out:
#          Adjusted Gross  Adjusted Gross Count  Percent  Height
# 0    (336.952, 629.964]                   165     82.5   0.825
# 1    (629.964, 921.518]                    24     12.0   0.120
# 2   (921.518, 1213.072]                     7      3.5   0.035
# 3  (1213.072, 1504.626]                     2      1.0   0.010
# 4   (1504.626, 1796.18]                     2      1.0   0.010

# %%
from matplotlib.ticker import PercentFormatter

millions['Adjusted Gross'].hist(bins=10, density=True) # density scale = true
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %%
x = millions['Adjusted Gross']
plt.hist(x, density=True)
plt.xlabel('Adjusted Gross (Million Dollars)')
plt.ylabel('Percent per Million Dollars')
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %% [markdown]
# ### 7.2.3. The Horizontal Axis

# %%
x = millions['Adjusted Gross']
plt.hist(x, bins=np.arange(300, 2001, 100), density=True)
plt.xlabel('Adjusted Gross (Million Dollars)')
plt.ylabel('Percent per Million Dollars')
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %% [markdown]
# ### 7.2.4. The Area Principle

# %% [markdown]
# ### 7.2.5. The Histogram: General Principles and Calculation

# %% [markdown]
# ### 7.2.6. The Vertical Axis: Density Scale

# %%
x = millions['Adjusted Gross']
plt.hist(x, bins=np.arange(300, 2001, 100), density=True)
plt.xlabel('Adjusted Gross (Million Dollars)')
plt.ylabel('Percent per Million Dollars')
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %%
# Calculate bins
# Define bins range
bins_range = np.arange(300, 2001, 100)

# Method1: Construct bins and Delay Count
bins = pd.cut(millions['Adjusted Gross'], bins_range, right=False).value_counts().reset_index(
    name='Adjusted Gross Count')
bins.rename(columns={'index': 'bins'}, inplace=True)

'''
# Method2: Construct bins and Delay Count
bins = millions.groupby(pd.cut(millions['Adjusted Gross'], bins_range, right=False))
bins = pd.DataFrame(bins['Adjusted Gross'].count().reset_index(name='Adjusted Gross Count'))
bins.rename(columns={'Adjusted Gross': 'bins'}, inplace=True)
bins
'''

bins[:3]
# Out:
#   Adjusted Gross  Adjusted Gross Count
# 0     [300, 400)                    68
# 1     [400, 500)                    60
# 2     [500, 600)                    32

# %% [markdown]
# ### 7.2.7. WHy Not Simple Plot the Counts?

# %%
uneven = np.array([300, 350, 400, 500, 1800])
x = millions['Adjusted Gross']
plt.hist(x, bins=uneven, density=True)
plt.xlabel('Adjusted Gross (Million Dollars)')
plt.ylabel('Percent per Million Dollars')
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %%
uneven = np.array([300, 350, 400, 500, 1800])
x = millions['Adjusted Gross']
plt.hist(x, bins=uneven)
plt.xlabel('Adjusted Gross (Million Dollars)')
plt.ylabel('count')
plt.show()

# %%
bins = pd.cut(millions['Adjusted Gross'], uneven).value_counts().reset_index(name='Adjusted Gross Count')
bins.rename(columns={'index': 'bins'}, inplace=True)
bins
# Out:
#   Adjusted Gross  Adjusted Gross Count
# 0    (500, 1800]                    72
# 1     (400, 500]                    60
# 2     (350, 400]                    54
# 3     (300, 350]                    14

# %%
uneven = np.array([300, 350, 400, 500, 1800])
x = millions['Adjusted Gross']
plt.hist(x, bins=uneven)
plt.xlabel('Adjusted Gross (Million Dollars)')
plt.ylabel('Percent per Million Dollars')
plt.show()

# %% [markdown]
# ### 7.2.8. Flat Tops and the Level of Detail

# %%
uneven = np.array([300, 350, 400, 500, 1800])
x = millions['Adjusted Gross']
plt.hist(x, bins=uneven, density=True)
plt.xlabel('Adjusted Gross (Million Dollars)')
plt.ylabel('Percent per Million Dollars')
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %%
uneven = np.array([300, 350, 400, 410, 420, 430, 440, 450, 460, 470, 480, 490, 500, 1800])
x = millions['Adjusted Gross']
plt.hist(x, bins=uneven, density=True)
plt.xlabel('Adjusted Gross (Million Dollars)')
plt.ylabel('Percent per Million Dollars')
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %% [markdown]
# ### 7.2.9. Computing All Heights

# %%
uneven = np.array([300, 350, 400, 500, 1800])
x = millions['Adjusted Gross']
plt.hist(x, bins=uneven, density=True)
plt.xlabel('Adjusted Gross (Million Dollars')
plt.ylabel('Percent per Million Dollars')
plt.show()

# %%
uneven = np.array([300, 350, 400, 500, 1800])
bins = pd.cut(millions['Adjusted Gross'], uneven, right=False).value_counts().reset_index(name='count')
bins.rename(columns={'index': 'bins'}, inplace=True)
bins
# Out:
#   Adjusted Gross  count
# 0    [500, 1800)     72
# 1     [400, 500)     60
# 2     [350, 400)     54
# 3     [300, 350)     14

# %%
bins['percent'] = bins['count'] / sum(bins['count']) * 100
bins
# Out:
#   Adjusted Gross  count  percent
# 0    [500, 1800)     72     36.0
# 1     [400, 500)     60     30.0
# 2     [350, 400)     54     27.0
# 3     [300, 350)     14      7.0

# %%
uneven = np.array([300, 350, 400, 500, 1800])
bins['width'] = [uneven[i + 1] - uneven[i] for i in range(len(uneven) - 1)]
bins
# Out:
#   Adjusted Gross  count  percent  width
# 0    [500, 1800)     72     36.0     50
# 1     [400, 500)     60     30.0     50
# 2     [350, 400)     54     27.0    100
# 3     [300, 350)     14      7.0   1300

# %%
bins['Height'] = bins.loc[:, 'count'] / sum(bins.loc[:, 'count'])
bins
# Out:
#           bins  count  percent  width  Height
# 0  [500, 1800)     72     36.0     50    0.36
# 1   [400, 500)     60     30.0     50    0.30
# 2   [350, 400)     54     27.0    100    0.27
# 3   [300, 350)     14      7.0   1300    0.07

# %%
uneven = np.array([300, 350, 400, 500, 1800])
x = millions['Adjusted Gross']
plt.hist(x, bins=uneven, density=True)
plt.xlabel('Adjusted Gross (Million Dollars')
plt.ylabel('Percent per Million Dollars')
plt.show()

# %% [markdown]
# ### 7.2.10. Differences Between Bar Charts and Histogram

# %% [markdown]
# ## 7.3. Overlaid Graphs

# %% [markdown]
# ### 7.3.1. Overlaid Scatter Plots

# %%
# Import dataset galton_subset.csv
heights = pd.read_csv(path_data + 'sons_heights.csv')
heights
# Out:
#      father  mother   son
# 0      78.5    67.0  73.2
# 1      75.5    66.5  73.5
# 2      75.0    64.0  71.0
# 3      75.0    64.0  70.5
# 4      75.0    58.5  72.0
# ..      ...     ...   ...
# 174    64.0    64.0  70.5
# 175    64.0    63.0  64.5
# 176    64.0    60.0  66.0
# 177    62.0    66.0  64.0
# 178    62.5    63.0  66.5
#
# [179 rows x 3 columns]

# %%
x, y, z = heights['son'], heights['father'], heights['mother']
plt.scatter(x, y, color='blue', alpha=0.5, label='father')
plt.scatter(x, z, color='red', alpha=0.5, label='mother')
plt.xlabel('son', fontsize=16)
plt.ylabel('height', fontsize=16)
plt.legend(loc=(1.0, 1.0))
plt.show()

# %% [markdown]
# ### 7.3.2. Overlaid Line Plots

# %%
# Read the full Census table
data = 'http://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2010-2019/nc-est2019-agesex-res.csv'
full_census_table = pd.read_csv(data)

# Extract four columns from full_census_table.
partial_census_table = full_census_table[['SEX', 'AGE', 'POPESTIMATE2019', 'POPESTIMATE2014']]

# Rename two columns
us_pop = partial_census_table.rename(columns={'POPESTIMATE2019': '2019', 'POPESTIMATE2014': '2014'}, inplace=False)

# Access the rows corresponding to all children, ages 0-18, sex 0 (male & female)
filter1 = us_pop['AGE'] <= 18
filter2 = us_pop['SEX'] == 0
children = us_pop.loc[filter1 & filter2]

# Drop column 'SEX'
children.drop(columns=['SEX'], inplace=True)
children
# Out:
# <ipython-input-154-78cc78ed9275>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   children.drop(columns=['SEX'], inplace=True)
#     AGE     2019     2014
# 0     0  3783052  3954787
# 1     1  3829599  3948891
# 2     2  3922044  3958711
# 3     3  3998665  4005928
# 4     4  4043323  4004032
# 5     5  4028281  4004576
# 6     6  4017227  4133372
# 7     7  4022319  4152666
# 8     8  4066194  4118349
# 9     9  4061874  4106068
# 10   10  4060940  4114558
# 11   11  4189261  4084457
# 12   12  4208387  4067187
# 13   13  4175221  4168095
# 14   14  4164459  4231353
# 15   15  4175459  4162828
# 16   16  4150420  4165925
# 17   17  4142425  4181940
# 18   18  4255827  4221344

# %%
x, y, z = children['AGE'], children['2014'], children['2019']
plt.plot(x, y, color='blue', alpha=0.5, label='2014')
plt.plot(x, z, color='orange', alpha=0.5, label='2019')
plt.xlabel('AGE', fontsize=16)
plt.legend(loc=(1.0, 1.0))
plt.show()

# %% [markdown]
# ### 7.3.3. Bar Charts

# %%
# Read CSV use_ca
usa_ca = pd.read_csv(path_data + 'usa_ca_2019.csv')
usa_ca
# Out:
#   Ethnicity/Race  USA All  CA All  USA Children  CA Children
# 0            API      5.8    15.1           4.9         11.5
# 1          Black     12.2     5.3          13.4          4.9
# 2       Hispanic     18.5    39.5          25.6         52.1
# 3          White     60.1    36.4          50.0         25.5
# 4          Other      3.4     3.7           6.1          6.0

# %%
new_usa_ca = usa_ca.set_index(keys=['Ethnicity/Race'], inplace=False)
ax = new_usa_ca.plot.barh()

# %%
new_usa_ca = usa_ca.set_index(keys=['Ethnicity/Race'], inplace=False)
new_usa_ca = new_usa_ca[['USA All', 'CA All']]
ax = new_usa_ca.plot.barh()

# %%
new_usa_ca = usa_ca.set_index(keys=['Ethnicity/Race'], inplace=False)
new_usa_ca = new_usa_ca[['CA All', 'CA Children']]
ax = new_usa_ca.plot.barh()
